# %% [markdown]
# This is the third assignment for the Coursera course "Advanced Machine Learning and Signal Processing"
#
# Just execute all cells one after the other and you are done - just note that in the last one you must update your email address (the one you've used for coursera) and obtain a submission token, you get this from the programming assignment directly on coursera.
#
# Please fill in the sections labelled with "###YOUR_CODE_GOES_HERE###"

# %% [markdown]
# This notebook is designed to run in a IBM Watson Studio default runtime (NOT the Watson Studio Apache Spark Runtime as the default runtime with 1 vCPU is free of charge). Therefore, we install Apache Spark in local mode for test purposes only. Please don't use it in production.
#
# In case you are facing issues, please read the following two documents first:
#
# https://github.com/IBM/skillsnetwork/wiki/Environment-Setup
#
# https://github.com/IBM/skillsnetwork/wiki/FAQ
#
# Then, please feel free to ask:
#
# https://coursera.org/learn/machine-learning-big-data-apache-spark/discussions/all
#
# Please make sure to follow the guidelines before asking a question:
#
# https://github.com/IBM/skillsnetwork/wiki/FAQ#im-feeling-lost-and-confused-please-help-me
#
#
# If running outside Watson Studio, this should work as well. In case you are running in an Apache Spark context outside Watson Studio, please remove the Apache Spark setup in the first notebook cells.

# %%
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown('# <span style="color:red">'+string+'</span>'))


if ('sc' in locals() or 'sc' in globals()):
    printmd('<<<<<!!!!! It seems that you are running in a IBM Watson Studio Apache Spark Notebook. Please run it in an IBM Watson Studio Default Runtime (without Apache Spark) !!!!!>>>>>')

# %%
# !pip install pyspark==2.4.5
# Out:
# Collecting pyspark==2.4.5
#   Downloading https://files.pythonhosted.org/packages/9a/5a/271c416c1c2185b6cb0151b29a91fff6fcaed80173c8584ff6d20e46b465/pyspark-2.4.5.tar.gz (217.8MB)
#      |████████████████████████████████| 217.8MB 173kB/s  eta 0:00:01     |█████████████████████▋          | 147.1MB 55.7MB/s eta 0:00:02
# Collecting py4j==0.10.7 (from pyspark==2.4.5)
#   Downloading https://files.pythonhosted.org/packages/e3/53/c737818eb9a7dc32a7cd4f1396e787bd94200c3997c72c1dbe028587bd76/py4j-0.10.7-py2.py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 41.6MB/s eta 0:00:01
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/bf/db/04/61d66a5939364e756eb1c1be4ec5bdce6e04047fc7929a3c3c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.7 pyspark-2.4.5

# %%
try:
    from pyspark import SparkContext, SparkConf
    from pyspark.sql import SparkSession
except ImportError as e:
    printmd('<<<<<!!!!! Please restart your kernel after installing Apache Spark !!!!!>>>>>')

# %%
sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))

spark = SparkSession \
    .builder \
    .getOrCreate()

# %%
# !wget https://github.com/IBM/coursera/raw/master/coursera_ml/a2.parquet
# Out:
# --2020-05-23 11:51:18--  https://github.com/IBM/coursera/raw/master/coursera_ml/a2.parquet
# Resolving github.com (github.com)... 140.82.118.3
# Connecting to github.com (github.com)|140.82.118.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/IBM/skillsnetwork/raw/master/coursera_ml/a2.parquet [following]
# --2020-05-23 11:51:19--  https://github.com/IBM/skillsnetwork/raw/master/coursera_ml/a2.parquet
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/IBM/skillsnetwork/master/coursera_ml/a2.parquet [following]
# --2020-05-23 11:51:19--  https://raw.githubusercontent.com/IBM/skillsnetwork/master/coursera_ml/a2.parquet
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.16.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.16.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59032 (58K) [application/octet-stream]
# Saving to: ‘a2.parquet’
#
# 100%[======================================>] 59,032      --.-K/s   in 0.004s
#
# 2020-05-23 11:51:19 (15.1 MB/s) - ‘a2.parquet’ saved [59032/59032]

# %% [markdown]
# Now it’s time to have a look at the recorded sensor data. You should see data similar to the one exemplified below….

# %%
df=spark.read.load('a2.parquet')

df.createOrReplaceTempView("df")
spark.sql("SELECT * from df").show()
# Out:
# +-----+-----------+-------------------+-------------------+-------------------+
# |CLASS|   SENSORID|                  X|                  Y|                  Z|
# +-----+-----------+-------------------+-------------------+-------------------+
# |    0|         26| 380.66434005495194| -139.3470983812975|-247.93697521077704|
# |    0|         29| 104.74324299209692| -32.27421440203938|-25.105013725863852|
# |    0| 8589934658| 118.11469236129976| 45.916682927433534| -87.97203782706572|
# |    0|34359738398| 246.55394030642543|-0.6122810693132044|-398.18662513951506|
# |    0|17179869241|-190.32584900181487|  234.7849657520335|-206.34483804019288|
# |    0|25769803830| 178.62396382387422| -47.07529438881511|  84.38310769821979|
# |    0|25769803831|  85.03128805189493|-4.3024316644854546|-1.1841857567516714|
# |    0|34359738411| 26.786262674736566| -46.33193951911338| 20.880756008396055|
# |    0| 8589934592|-16.203752396859194| 51.080957032176954| -96.80526656416971|
# |    0|25769803852|   47.2048142440404|  -78.2950899652916| 181.99604091494786|
# |    0|34359738369| 15.608872398939273| -79.90322809181754|  69.62150711098005|
# |    0|         19|-4.8281721129789315| -67.38050508399905| 221.24876396496404|
# |    0|         54| -98.40725712852762|-19.989364074314732|  -302.695196085276|
# |    0|17179869313| 22.835845394816594|   17.1633660118843| 32.877914832011385|
# |    0|34359738454|  84.20178070080324| -32.81572075916947| -48.63517643958031|
# |    0|          0|  56.54732521345129| -7.980106018032676|  95.05162719436447|
# |    0|17179869201|  -57.6008655247749|  5.135393798773895| 236.99158698947267|
# |    0|17179869308| -65.59264738389012| -48.92660057215126| -61.58970715383383|
# |    0|25769803790|  34.82337351291005|  9.483542084393937|  197.6066372962772|
# |    0|25769803825|  39.80573823439121|-0.7955236412785212| -79.66652640650325|
# +-----+-----------+-------------------+-------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# Let’s check if we have balanced classes – this means that we have roughly the same number of examples for each class we want to predict. This is important for classification but also helpful for clustering

# %%
spark.sql("SELECT count(class), class from df group by class").show()
# Out:
# +------------+-----+
# |count(class)|class|
# +------------+-----+
# |        1416|    1|
# |        1626|    0|
# +------------+-----+

# %% [markdown]
# Let's create a VectorAssembler which consumes columns X, Y and Z and produces a column “features”

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols=["X","Y","Z"],
                                  outputCol="features")

# %% [markdown]
# Please insatiate a clustering algorithm from the SparkML package and assign it to the clust variable. Here we don’t need to take care of the “CLASS” column since we are in unsupervised learning mode – so let’s pretend to not even have the “CLASS” column for now – but it will become very handy later in assessing the clustering performance. PLEASE NOTE – IN REAL-WORLD SCENARIOS THERE IS NO CLASS COLUMN – THEREFORE YOU CAN’T ASSESS CLASSIFICATION PERFORMANCE USING THIS COLUMN

# %%
from pyspark.ml.clustering import KMeans

clust = KMeans().setK(3).setSeed(1)

# %% [markdown]
# Let’s train...

# %%
from pyspark.ml import Pipeline
pipeline = Pipeline(st
# |    0| 8589934715|  192.86941424710005| -102.91384180764416|   -64.7572971722237|[192.869414247100...|         2|
# |    0| 8589934719|  -140.2412309653335|  25.131344837381246|  187.96580200182916|[-140.24123096533...|         0|
# |    0|17179869184|   75.15154659129712|    9.78330620461233|  -348.6887237078119|[75.1515465912971...|         1|
# ...
#  Row(features=DenseVector([-110.6044, -6.5035, 249.7249])),
#  Row(features=DenseVector([-94.5559, 85.0845, 239.1817])),
#  Row(features=DenseVector([31.9422, -7.6802, 214.5114])),
#  Row(features=DenseVector([147.3333, -7.117, 74.644])),
#  Row(features=DenseVector([-224.5848, 137.0846, -9.999])),
#  Row(features=DenseVector([-12.6632, 1.5236, -60.577])),
#  Row(features=DenseVector([36.7436, -21.7881, -138.6237])),
#  Row(features=DenseVector([-95.1121, 52.4793, 277.078])),
#  Row(features=DenseVector([35.3036, 63.2663, -317.8544])),
#  Row(features=DenseVector([58.7451, -56.1083, 117.7658])),
#  Row(features=DenseVector([-0.77, -0.6079, 15.1153])),
#  Row(features=DenseVector([-1.1469, -6.2154, -4.641])),
#  Row(features=DenseVector([7.3558, 1.0119, -6.9705])),
#  Row(features=DenseVector([1.1818, -4.6108, 0.7467])),
#  Row(features=DenseVector([-9.0656, 5.9709, 3.5537])),
#  Row(features=DenseVector([-2.877, -3.7481, -8.5335])),
#  Row(features=DenseVector([-4.0065, -2.2678, -0.2941])),
#  Row(features=DenseVector([0.1989, -0.1395, -6.8299])),
#  Row(features=DenseVector([2.3679, -1.1267, -1.0891])),
#  Row(features=DenseVector([3.6888, 1.794, 5.9128])),
#  Row(features=DenseVector([-1.649, 2.1326, -0.3497])),
#  Row(features=DenseVector([5.1832, -1.0663, 4.5496])),
#  Row(features=DenseVector([-4.8316, 3.0489, 3.8676])),
#  Row(features=DenseVector([2.3363, 5.2497, 7.6151])),
#  Row(features=DenseVector([5.3679, -2.2061, -2.8566])),
#  Row(features=DenseVector([-4.1359, 3.2899, -5.846])),
#  Row(features=DenseVector([4.4485, -1.0295, -0.8985])),
#  Row(features=DenseVector([8.2756, 1.0281, -4.0546])),
#  Row(features=DenseVector([7.4698, -1.9183, -27.4417])),
#  Row(features=DenseVector([-1.6126, -2.3661, -5.2219])),
#  Row(features=DenseVector([-0.0155, -2.2313, -2.301])),
#  Row(features=DenseVector([-0.7899, 2.6916, 4.3537])),
#  Row(features=DenseVector([-0.5892, 1.7602, 11.0938])),
#  Row(features=DenseVector([0.1688, -3.9016, 8.2329])),
#  Row(features=DenseVector([0.8674, -6.7861, -1.7159])),
#  Row(features=DenseVector([-2.102, -4.2151, -5.8255])),
#  Row(features=DenseVector([-3.7889, -1.5385, 1.606])),
#  Row(features=DenseVector([5.405, -2.4959, -6.3384])),
#  Row(features=DenseVector([7.718, -0.1692, 1.6403])),
#  Row(features=DenseVector([0.6553, 1.1062, 5.1534])),
#  Row(features=DenseVector([-0.2434, 1.193, 12.8069])),
#  Row(features=DenseVector([-3.3023, 0.0339, 7.933])),
#  Row(features=DenseVector([0.0358, 3.6344, 7.1369])),
#  Row(features=DenseVector([-5.3813, 0.0281, -1.9984])),
#  Row(features=DenseVector([-6.0322, 6.6106, 19.4305])),
#  Row(features=DenseVector([3.089, 2.3562, 21.6829])),
#  Row(features=DenseVector([-1.2206, -1.5453, 13.041])),
#  Row(features=DenseVector([7.2622, -0.7355, -12.6908])),
#  Row(features=DenseVector([8.3097, -5.8382, -8.904])),
#  Row(features=DenseVector([-2.8932, 2.3444, 5.7344])),
#  Row(features=DenseVector([-2.9652, -5.1398, -22.3629])),
#  Row(features=DenseVector([-5.121, -0.375, 6.6827])),
#  Row(features=DenseVector([-7.3411, -0.6864, -5.8572])),
#  Row(features=DenseVector([9.6626, -2.3737, -9.2194])),
#  Row(features=DenseVector([-9.6575, -1.7778, 1.7698])),
#  Row(features=DenseVector([1.8792, -1.5599, -0.2129])),
#  Row(features=DenseVector([5.9227, -1.1912, -13.3629])),
#  Row(features=DenseVector([-0.3206, -2.1532, -19.1305])),
#  Row(features=DenseVector([-6.664, -1.9947, -2.3651])),
#  Row(features=DenseVector([1.0186, -1.0701, 2.5805])),
#  Row(features=DenseVector([2.9245, -0.7597, -2.6197])),
#  Row(features=DenseVector([1.9468, 0.5999, 9.5961])),
#  Row(features=DenseVector([7.1179, 3.3641, 0.8172])),
#  Row(features=DenseVector([-1.3429, -1.1963, 3.6892])),
#  Row(features=DenseVector([5.7623, 3.7097, 12.0402])),
#  Row(features=DenseVector([0.7444, 4.4274, -13.514])),
#  Row(features=DenseVector([5.2597, -1.0256, -6.5885])),
#  Row(features=DenseVector([10.2518, 5.1403, -0.6465])),
#  Row(features=DenseVector([7.6825, -2.4517, 6.4083])),
#  Row(features=DenseVector([-9.4733, 3.7308, 21.0083])),
#  Row(features=DenseVector([0.1016, 3.4745, 16.8236])),
#  Row(features=DenseVector([0.394, -1.7403, 5.6361])),
#  Row(features=DenseVector([6.4143, 2.2044, -0.7909])),
#  Row(features=DenseVector([-2.7742, -2.9071, 3.9801])),
#  Row(features=DenseVector([-2.016, 1.8101, -12.3051])),
#  Row(features=DenseVector([2.1565, 0.0119, -9.7058])),
#  Row(features=DenseVector([5.0306, 0.3673, -13.768])),
#  Row(features=DenseVector([-2.9321, -4.1675, -3.7484])),
#  Row(features=DenseVector([8.8844, -0.5799, -3.9941])),
#  Row(features=DenseVector([0.6497, 1.0971, 13.9451])),
#  Row(features=DenseVector([-0.0503, 8.0621, 14.5994])),
#  Row(features=DenseVector([1.4147, 3.1706, 0.9505])),
#  Row(features=DenseVector([1.3178, 2.2924, 7.5583])),
#  Row(features=DenseVector([2.2332, -5.214, -13.0193])),
#  Row(features=DenseVector([6.6373, -1.6418, -7.2481])),
#  Row(features=DenseVector([-3.3023, 0.0339, 7.933])),
#  Row(features=DenseVector([-1.1469, -6.2154, -4.641])),
#  Row(features=DenseVector([-1.6969, -0.2711, 8.7275])),
#  Row(features=DenseVector([5.5815, 4.0144, 2.3009])),
#  Row(features=DenseVector([-0.1451, -3.4937, 6.5795])),
#  Row(features=DenseVector([14.05, 6.4229, -1.5102])),
#  Row(features=DenseVector([1.6742, 7.1003, 2.0287])),
#  Row(features=DenseVector([7.6825, -2.4517, 6.4083])),
#  Row(features=DenseVector([1.4952, -4.5003, 3.8256])),
#  Row(features=DenseVector([-6.8855, -5.2448, -3.1077])),
#  Row(features=DenseVector([0.8008, -2.761, -0.3459])),
#  Row(features=DenseVector([-8.4042, 1.7691, -1.51])),
#  Row(features=DenseVector([-1.3888, -3.5142, -2.0464])),
#  Row(features=DenseVector([-5.2535, 0.0878, 2.0441])),
#  Row(features=DenseVector([-3.8152, -3.3931, -4.4725])),
#  Row(features=DenseVector([-2.6523, -3.2787, -5.4911])),
#  Row(features=DenseVector([-3.81, 0.12, 1.13])),
#  Row(features=DenseVector([-3.8425, -5.3718, -5.5549])),
#  Row(features=DenseVector([3.9562, 3.7446, 14.4885])),
#  Row(features=DenseVector([8.0286, 0.3105, 15.1627])),
#  Row(features=DenseVector([-2.154, 5.1565, 5.2089])),
#  Row(features=DenseVector([0.1688, -3.9016, 8.2329])),
#  Row(features=DenseVector([-2.0197, 0.9169, 8.9602])),
#  Row(features=DenseVector([4.0779, -5.7932, 8.1548])),
#  Row(features=DenseVector([1.2902, 0.7776, -4.1598])),
#  Row(features=DenseVector([8.3097, -5.8382, -8.904])),
#  Row(features=DenseVector([-4.17, -0.32, -0.48])),
#  Row(features=DenseVector([6.4142, 0.8565, -5.44])),
#  Row(features=DenseVector([-0.55, -0.94, 14.99])),
#  Row(features=DenseVector([-5.5981, -3.0089, -3.2477])),
#  Row(features=DenseVector([-8.4042, 1.7691, -1.51])),
#  Row(features=DenseVector([-6.0582, 7.2127, 5.8891])),
#  Row(features=DenseVector([-6.1559, -6.4726, -6.7507])),
#  Row(features=DenseVector([-7.7919, -0.8156, 6.2801])),
#  Row(features=DenseVector([-4.0065, -2.2678, -0.2941])),
#  Row(features=DenseVector([-3.947, 3.0098, -0.3406])),
#  Row(features=DenseVector([-6.1559, -6.4726, -6.7507])),
#  Row(features=DenseVector([-4.1959, -5.3575, -8.5675])),
#  Row(features=DenseVector([-0.9014, -5.7992, 0.5672])),
#  Row(features=DenseVector([-2.0656, 0.6599, -3.5524])),
#  Row(features=DenseVector([-9.0656, 5.9709, 3.5537])),
#  Row(features=DenseVector([-1.3888, -3.5142, -2.0464])),
#  Row(features=DenseVector([8.8844, -0.5799, -3.9941])),
#  Row(features=DenseVector([-5.3364, -0.2498, 2.0886])),
#  Row(features=DenseVector([2.2332, -5.214, -13.0193])),
#  Row(features=DenseVector([-2.5016, -2.2318, 7.2817])),
#  Row(features=DenseVector([4.29, -2.5616, 1.4977])),
#  Row(features=DenseVector([-1.3749, 1.2483, 1.0078])),
#  Row(features=DenseVector([6.5341, 1.8535, -0.5769])),
#  Row(features=DenseVector([-0.1451, -3.4937, 6.5795])),
#  Row(features=DenseVector([-0.55, -0.94, 14.99])),
#  Row(features=DenseVector([-3.6795, -0.8938, -9.6791])),
#  Row(features=DenseVector([5.9227, -1.1912, -13.3629])),
#  Row(features=DenseVector([-4.1359, 3.2899, -5.846])),
#  Row(features=DenseVector([-0.3626, 4.6201, -5.1232])),
#  Row(features=DenseVector([0.0792, -1.0464, -16.7772])),
#  Row(features=DenseVector([-6.1184, 2.2658, 3.1023])),
#  Row(features=DenseVector([-3.2253, 2.849, 5.5239])),
#  Row(features=DenseVector([8.6662, 2.5631, 8.2227])),
#  Row(features=DenseVector([-4.4721, 0.9132, 8.1001])),
#  Row(features=DenseVector([2.7113, -1.9663, -7.4157])),
#  Row(features=DenseVector([-2.9321, -4.1675, -3.7484])),
#  Row(features=DenseVector([4.1941, -1.8154, 8.2458])),
#  Row(features=DenseVector([3.5124, -3.4018, -14.336])),
#  Row(features=DenseVector([4.6385, -4.2552, 1.4388])),
#  Row(features=DenseVector([-2.3736, -0.2288, -10.4788])),
#  Row(features=DenseVector([-1.1173, 3.7353, 1.2868])),
#  Row(features=DenseVector([0.5661, -1.7323, -1.6583])),
#  Row(features=DenseVector([6.0582, -2.1151, -10.7935])),
#  Row(features=DenseVector([-13.2005, -4.1852, -6.4475])),
#  Row(features=DenseVector([-0.5785, -6.5672, -15.465])),
#  Row(features=DenseVector([4.0772, 3.2711, -0.9419])),
#  Row(features=DenseVector([5.405, -2.4959, -6.3384])),
#  Row(features=DenseVector([-0.9214, 1.8412, -7.7741])),
#  Row(features=DenseVector([12.6118, 1.053, 9.4907])),
#  Row(features=DenseVector([-1.23, -20.97, -26.23])),
#  Row(features=DenseVector([-0.737, 0.5219, -3.0411])),
#  Row(features=DenseVector([-2.6401, 3.6287, -7.8896])),
#  Row(features=DenseVector([11.3357, 6.0989, 18.5026])),
#  Row(features=DenseVector([1.6742, 7.1003, 2.0287])),
#  Row(features=DenseVector([-0.0503, 8.0621, 14.5994])),
#  Row(features=DenseVector([0.0792, -1.0464, -16.7772])),
#  Row(features=DenseVector([-4.8316, 3.0489, 3.8676])),
#  Row(features=DenseVector([2.08, 2.7266, -9.4727])),
#  Row(features=DenseVector([-0.9307, -0.0694, 10.4394])),
#  Row(features=DenseVector([10.8864, -0.1644, -9.2542])),
#  Row(features=DenseVector([0.9089, 0.4922, 7.0164])),
#  Row(features=DenseVector([2.3245, -1.4418, -3.3074])),
#  Row(features=DenseVector([5.7623, 3.7097, 12.0402])),
#  Row(features=DenseVector([-2.154, 5.1565, 5.2089])),
#  Row(features=DenseVector([-4.5166, 1.1274, 11.605])),
#  Row(features=DenseVector([2.9191, 3.6562, 21.1666])),
#  Row(features=DenseVector([-3.0306, 5.9108, 10.0358])),
#  Row(features=DenseVector([6.2695, 4.0417, -3.9677])),
#  Row(features=DenseVector([12.6118, 1.053, 9.4907])),
#  Row(features=DenseVector([-10.3935, 2.3945, 1.8226])),
#  Row(features=DenseVector([-8.5438, -0.9606, -18.7547])),
#  Row(features=DenseVector([-1.7928, -0.7691, -6.5259])),
#  Row(features=DenseVector([-4.7419, 5.828, 14.0958])),
#  Row(features=DenseVector([10.1489, -1.4801, -0.4639])),
#  Row(features=DenseVector([0.2444, -0.8255, 5.5789])),
#  Row(features=DenseVector([-5.1019, -0.0995, -0.294])),
#  Row(features=DenseVector([-1.9397, -0.9195, 5.3373])),
#  Row(features=DenseVector([-2.1264, -3.0905, -14.4831])),
#  Row(features=DenseVector([-2.5461, -0.2705, -9.4899])),
#  Row(features=DenseVector([-0.9014, -5.7992, 0.5672])),
#  Row(features=DenseVector([-3.5267, -1.3422, -5.779])),
#  Row(features=DenseVector([-0.5892, 1.7602, 11.0938])),
#  Row(features=DenseVector([3.2362, 0.9684, -9.2753])),
#  Row(features=DenseVector([-0.2434, 1.193, 12.8069])),
#  Row(features=DenseVector([-1.3918, 0.5009, 1.8042])),
#  Row(features=DenseVector([0.5124, 5.3128, 0.2962])),
#  Row(features=DenseVector([-1.444, 0.0112, -2.5568])),
#  Row(features=DenseVector([7.9766, 0.0874, 7.5102])),
#  Row(features=DenseVector([2.3654, 2.4891, -5.5928])),
#  Row(features=DenseVector([1.7023, 0.9935, -14.1637])),
#  Row(features=DenseVector([-7.7919, -0.8156, 6.28])),
#  Row(features=DenseVector([4.3538, 3.7799, -0.3919])),
#  Row(features=DenseVector([-3.2646, 3.4846, 21.8303])),
#  Row(features=DenseVector([9.403, 0.5217, -3.7342])),
#  Row(features=DenseVector([0.4934, -1.2467, 5.9313])),
#  Row(features=DenseVector([-4.1618, -0.5066, -21.8816])),
#  Row(features=DenseVector([-5.829, 3.889, -5.2335])),
#  Row(features=DenseVector([-2.633, 2.11, 3.3522])),
#  Row(features=DenseVector([2.8365, -1.5474, 10.0385])),
#  Row(features=DenseVector([-0.0521, -4.4399, -8.425])),
#  Row(features=DenseVector([0.1928, 2.7944, 12.7318])),
#  Row(features=DenseVector([-4.4607, 4.3924, 1.203])),
#  Row(features=DenseVector([-3.3545, -7.5504, -12.6381])),
#  Row(features=DenseVector([1.6931, 1.9388, -2.9321])),
#  Row(features=DenseVector([3.0712, 3.622, 16.316])),
#  Row(features=DenseVector([0.1928, 2.7944, 12.7318])),
#  Row(features=DenseVector([2.1565, 0.0119, -9.7058])),
#  Row(features=DenseVector([6.6676, -2.3461, -0.333])),
#  Row(features=DenseVector([1.4631, -3.2103, -0.8813])),
#  Row(features=DenseVector([-6.1184, 2.2658, 3.1023])),
#  Row(features=DenseVector([-0.5764, 3.112, 2.1465])),
#  Row(features=DenseVector([-9.4733, 3.7308, 21.0083])),
#  Row(features=DenseVector([-1.2206, -1.5453, 13.041])),
#  Row(features=DenseVector([8.5063, -1.3922, -1.0192])),
#  Row(features=DenseVector([-2.3565, -0.1635, -3.768])),
#  Row(features=DenseVector([2.3654, 2.4891, -5.5928])),
#  Row(features=DenseVector([-4.0986, -1.9114, -15.0901])),
#  Row(features=DenseVector([-2.7451, -4.3217, -13.6588])),
#  Row(features=DenseVector([-2.9652, -5.1398, -22.3629])),
#  Row(features=DenseVector([-1.3682, 0.6363, -2.4549])),
#  Row(features=DenseVector([4.0417, 1.3003, 1.081])),
#  Row(features=DenseVector([1.2676, -4.4334, -20.0012])),
#  Row(features=DenseVector([1.7325, 3.3039, -4.6311])),
#  Row(features=DenseVector([6.6676, -2.3461, -0.333])),
#  Row(features=DenseVector([-0.8611, -3.4476, 4.9356])),
#  Row(features=DenseVector([-0.7899, 2.6916, 4.3537])),
#  Row(features=DenseVector([7.2639, 1.4266, -5.0376])),
#  Row(features=DenseVector([5.2597, -1.0256, -6.5885])),
#  Row(features=DenseVector([-9.5177, -0.8175, -4.7681])),
#  Row(features=DenseVector([-3.032, -0.3367, 2.6777])),
#  Row(features=DenseVector([3.6888, 1.794, 5.9128])),
#  Row(features=DenseVector([-3.8643, 7.5762, 20.886])),
#  Row(features=DenseVector([-5.5981, -3.0089, -3.2477])),
#  Row(features=DenseVector([0.5079, 1.8573, -0.0974])),
#  Row(features=DenseVector([-2.2609, 3.3028, 1.8989])),
#  Row(features=DenseVector([-8.5438, -0.9606, -18.7547])),
#  Row(features=DenseVector([4.2219, 4.1559, 4.2015])),
#  Row(features=DenseVector([4.7616, -3.1037, -0.4154])),
#  Row(features=DenseVector([7.1447, 2.5593, 11.239])),
#  Row(features=DenseVector([11.3357, 6.0989, 18.5026])),
#  Row(features=DenseVector([-3.2852, 1.1575, 8.0199])),
#  Row(features=DenseVector([1.1818, -4.6108, 0.7467])),
#  Row(features=DenseVector([4.3518, 3.7364, -1.2669])),
#  Row(features=DenseVector([-0.0623, -7.8177, -12.7437])),
#  Row(features=DenseVector([4.2178, -1.1277, 3.0319])),
#  Row(features=DenseVector([-0.3183, 5.6298, 1.516])),
#  Row(features=DenseVector([-3.2236, -3.8753, 3.1929])),
#  Row(features=DenseVector([-2.7451, -4.3217, -13.6589])),
#  Row(features=DenseVector([-0.3161, -0.1422, -15.7691])),
#  Row(features=DenseVector([-0.1608, -2.6724, -3.6945])),
#  Row(features=DenseVector([0.0833, -4.2215, 4.865])),
#  Row(features=DenseVector([-0.8818, 0.0575, -6.2698])),
#  Row(features=DenseVector([-3.1325, 0.4756, 5.0768])),
#  Row(features=DenseVector([-1.2376, -6.5147, -14.8493])),
#  Row(features=DenseVector([3.1017, 3.136, 6.7796])),
#  Row(features=DenseVector([5.5117, 0.4978, -6.3883])),
#  Row(features=DenseVector([-0.3749, -0.0717, 2.4542])),
#  Row(features=DenseVector([0.9089, 0.4922, 7.0164])),
#  Row(features=DenseVector([-0.0521, -4.4399, -8.425])),
#  Row(features=DenseVector([2.6143, -1.8449, -12.263])),
#  Row(features=DenseVector([-0.3161, -0.1422, -15.7691])),
#  Row(features=DenseVector([-3.5315, 6.8707, 18.3843])),
#  Row(features=DenseVector([-2.633, 2.11, 3.3522])),
#  Row(features=DenseVector([6.1099, 4.5019, 7.2329])),
#  Row(features=DenseVector([-0.5764, 3.112, 2.1465])),
#  Row(features=DenseVector([1.1157, 4.3344, -2.4388])),
#  Row(features=DenseVector([0.7244, -0.2248, 7.2767])),
#  Row(features=DenseVector([-7.3411, -0.6864, -5.8573])),
#  Row(features=DenseVector([0.8008, -2.761, -0.3459])),
#  Row(features=DenseVector([-1.7928, -0.7691, -6.5259])),
#  Row(features=DenseVector([7.1447, 2.5593, 11.239])),
#  Row(features=DenseVector([4.0417, 1.3003, 1.081])),
#  Row(features=DenseVector([-0.7371, 0.5219, -3.0411])),
#  Row(features=DenseVector([0.7846, -4.191, 0.2515])),
#  Row(features=DenseVector([4.5131, -0.1561, 14.9493])),
#  Row(features=DenseVector([-2.7398, 7.9795, 26.9456])),
#  Row(features=DenseVector([-3.81, 0.12, 1.13])),
#  ...]

# %%
prediction.createOrReplaceTempView('prediction')
spark.sql('''
select max(correct)/max(total) as accuracy from (

    select sum(correct) as correct, count(correct) as total from (
        select case when class != prediction then 1 else 0 end as correct from prediction 
    ) 
    
    union
    
    select sum(correct) as correct, count(correct) as total from (
        select case when class = prediction then 1 else 0 end as correct from prediction 
    ) 
)
''').rdd.map(lambda row: row.accuracy).collect()[0]
# Out:
# 0.646285338593031

# %% [markdown]
# If you reached at least 55% of accuracy you are fine to submit your predictions to the grader. Otherwise please experiment with parameters setting to your clustering algorithm, use a different algorithm or just re-record your data and try to obtain. In case you are stuck, please use the Coursera Discussion Forum. Please note again – in a real-world scenario there is no way in doing this – since there is no class label in your data. Please have a look at this further reading on clustering performance evaluation https://en.wikipedia.org/wiki/Cluster_analysis#Evaluation_and_assessment

# %%
# !rm -f rklib.py
# !wget https://raw.githubusercontent.com/IBM/coursera/master/rklib.py
# Out:
# --2020-05-23 09:16:34--  https://raw.githubusercontent.com/IBM/coursera/master/rklib.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.16.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.16.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2540 (2.5K) [text/plain]
# Saving to: ‘rklib.py’
#
# 100%[======================================>] 2,540       --.-K/s   in 0s
#
# 2020-05-23 09:16:34 (36.9 MB/s) - ‘rklib.py’ saved [2540/2540]

# %%
# !rm -Rf a2_m3.json

# %%
prediction= prediction.repartition(1)
prediction.write.json('a2_m3.json')

# %%
import zipfile
import os

def zipdir(path, ziph):
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file))

zipf = zipfile.ZipFile('a2_m3.json.zip', 'w', zipfile.ZIP_DEFLATED)
zipdir('a2_m3.json', zipf)
zipf.close()

# %%
# !base64 a2_m3.json.zip > a2_m3.json.zip.base64

# %%
from rklib import submit
key = "pPfm62VXEeiJOBL0dhxPkA"
part = "EOTMs"
email = "kalpitgupta369@gmail.com"
token = "PMTFUz265Z5UNNnF" # (have a look here if you need more information on how to obtain the token https://youtu.be/GcDo0Rwe06U?t=276)


with open('a2_m3.json.zip.base64', 'r') as myfile:
    data=myfile.read()
submit(email, token, key, part, [part], data)
# Out:
# Submission successful, please check on the coursera grader page for the status
# -------------------------
# {"elements":[{"itemId":"Cu6KW","id":"f_F-qCtuEei_fRLwaVDk3g~Cu6KW~G0NIo5zWEeqSegrysBV4gQ","courseId":"f_F-qCtuEei_fRLwaVDk3g"}],"paging":{},"linked":{}}
# -------------------------
