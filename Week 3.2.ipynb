# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import seaborn as sns

# %%
df1= pd.read_csv(r'C:\Users\Kalpit\Downloads\table-1.csv')
df2=pd.read_csv(r'C:\Users\Kalpit\Downloads\Geospatial_Coordinates.csv')
df1=df1[df1.Borough!='Not assigned']
df= pd.concat([df1,df2], axis=1, join='inner')
df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 95          M6N              York
# 98          M9N              York
# 99          M1P       Scarborough
# 100         M2P        North York
# 102         M4P   Central Toronto
#
#                                           Neighborhood Postal Code   Latitude  \
# 2                                            Parkwoods         M1E  43.763573
# 3                                     Victoria Village         M1G  43.770992
# 4                            Regent Park, Harbourfront         M1H  43.773136
# 5                     Lawrence Manor, Lawrence Heights         M1J  43.744734
# 6          Queen's Park, Ontario Provincial Government         M1K  43.727929
# ..                                                 ...         ...        ...
# ...
